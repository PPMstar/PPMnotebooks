# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Toggle Code"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Toggle Code"></form>

# %% [markdown]
# # Spacetime diagrams for the F5 run

# %%
import time
import utils
from ppm import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib nbagg

prof = yprofile('/rpod2/PPM/YProfiles/AGBTP_M2.0Z1.e-5/F5')
# Out:
# /usr/local/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# Reading attributes from file  YProfile-01-1169.bobaaa
# Analyzing headers ...
# There are 1170 YProfile files in the /rpod2/PPM/YProfiles/AGBTP_M2.0Z1.e-5/F5 directory.
# Ndump values range from 0 to 1169
# Time values range from 86.5493 to 101263.0

# %% [markdown]
# ## FV H+He

# %%
FV_cmap_str = '''
Cnot:   0 0.000000000 0.000000000 0.000000000
Cnot:   24 0.000000000 0.000000000 0.392156900
Cnot:   41 0.000000000 0.501960800 0.501960800
Cnot:   81 0.000000000 1.000000000 1.000000000
Cnot:   115 1.000000000 1.000000000 1.000000000
Cnot:   153 1.000000000 1.000000000 0.000000000
Cnot:   197 1.000000000 0.000000000 0.000000000
Cnot:   238 0.250980400 0.000000000 0.000000000
Cnot:   255 0.000000000 0.000000000 0.000000000
Anot:   0 0.000000000
Anot:   8 0.031372550
Anot:   20 0.062745100
Anot:   32 0.784313700
Anot:   133 1.000000000
Anot:   153 0.894117700
Anot:   197 0.243137300
Anot:   241 0.258823500
Anot:   255 0.000000000
'''
cmap = colourmap_from_str(FV_cmap_str, segment=(5, 251))

ifig = 1; plt.close(ifig); fig = plt.figure(ifig, figsize = (7., 2.25), dpi=150)
prof.spacetime_diagram('FV H+He', 1170, fig, rlim=(8., 33.), vlim=(1e-8, 1e0), cmap=cmap)
fig.tight_layout()
fig.savefig('sd_F5_FV_HHe_600dpi.pdf', dpi=600)
fig.savefig('sd_F5_FV_HHe_300dpi.pdf', dpi=300)
# Out:
# <img src="data:image/png;base64,...">
# Processing will be done in 174 s.
# Processing will be done in 160 s.
# Processing will be done in 122 s.
# Processing will be done in 70 s.
# Processing will be done in 34 s.

# %% [markdown]
# ## enuc_C12pg

# %%
airmu = 1.39165
cldmu = 0.725
fkair = 0.203606102635
fkcld = 0.885906040268
AtomicNoair = 6.65742024965
AtomicNocld = 1.34228187919
zero_intervals = None
#zero_intervals = (0., 5.33144E+04)
ifig = 2; plt.close(ifig); fig = plt.figure(ifig, figsize = (7., 2.25), dpi=150)
prof.spacetime_diagram('enuc_C12pg', 1170, fig, rlim=(8., 33.), vlim=(1e9, 1e13), \
                       zero_intervals=zero_intervals, cmap='inferno', airmu=airmu, \
                       cldmu=cldmu, fkair=fkair, fkcld=fkcld, AtomicNoair=AtomicNoair, \
                       AtomicNocld=AtomicNocld, corr_fact=1.5)
fig.tight_layout()
fig.savefig('sd_F5_enuc_C12pg_600dpi.pdf', dpi=600)
fig.savefig('sd_F5_enuc_C12pg_300dpi.pdf', dpi=300)
# Out:
# <img src="data:image/png;base64,...">
# Processing will be done in 681 s.
# Processing will be done in 662 s.
# Processing will be done in 638 s.
# Processing will be done in 614 s.
# Processing will be done in 591 s.
# Processing will be done in 568 s.
# Processing will be done in 544 s.
# Processing will be done in 520 s.
# Processing will be done in 496 s.
# Processing will be done in 449 s.
# Processing will be done in 408 s.
# Processing will be done in 369 s.
# Processing will be done in 332 s.
# Processing will be done in 296 s.
# Processing will be done in 261 s.
# Processing will be done in 228 s.
# Processing will be done in 195 s.
# Processing will be done in 164 s.
# Processing will be done in 134 s.
# Processing will be done in 105 s.
# Processing will be done in 75 s.
# Processing will be done in 47 s.
# Processing will be done in 18 s.

# %% [markdown]
# ## Ek

# %%
ifig = 3; plt.close(ifig); fig = plt.figure(ifig, figsize = (7., 2.25), dpi=150)
prof.spacetime_diagram('Ek', 1170, fig, rlim=(8., 33.), vlim=(1e10, 3e12))
fig.tight_layout()
fig.savefig('sd_F5_Ek_600dpi.pdf', dpi=600)
fig.savefig('sd_F5_Ek_300dpi.pdf', dpi=300)
# Out:
# <img src="data:image/png;base64,...">
# Processing will be done in 93 s.
# Processing will be done in 69 s.
# Processing will be done in 32 s.
# Processing will be done in 2 s.
