# %% [markdown]
# # Plotting Radial Buckets

# %%
#for using custom PyPPM for development:
import sys
sys.path.insert(0, '/home/user/test2/test/')

# %pylab nbagg
import ppmpy.ppm as ppm

sys.path.insert(0,'/data/ppm_rpod2/lib/lcse/')
import rprofile as rprofile
import os
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_dir = '/data/ppm_rpod2/RProfiles/'
# !ls /data/ppm_rpod2/RProfiles/
# Out:
# AGBTP_M2.0Z1.e-5  C-ingestion  O-shell-M25  O-shell-mixing  sakurai

# %%
project = 'AGBTP_M2.0Z1.e-5'
# !ls /data/ppm_rpod2/RProfiles/AGBTP_M2.0Z1.e-5/
# Out:
# F3  F4	F4e  F4f  F5  F9

# %%
data_path = os.path.join(data_dir,project,'F4')
rp_set = rprofile.rprofile_set(data_path)
rp = rp_set.get_dump(100)
rp.get('radtop')
# Out:
# 29.009326934814453

# %%
rp.get('radbase')
# Out:
# 11.18260383605957

# %%
ppm.plot_boundary_evolution(data_path, 27., 31., 700,sparse=20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
r_lim = (27, 30.5)
ut_lim = (1e-3, 19.)
dutdr_lim = (-0.099, 0.02)
dump = 560
hist_dmin = dump - 5
hist_dmax = dump + 5
ppm.upper_bound_ut(data_path,dump, hist_dmin, hist_dmax,r1 = r_lim[0],r2 = 31, derivative = False,
              ylims = [1e-3,19.])
# Out:
# <img src="data:image/png;base64,..." width="678">

# %%
ppm.upper_bound_ut(data_path,dump, hist_dmin, hist_dmax,r1 = r_lim[0],r2 = 31, derivative = True,
              ylims = (-0.099, 0.02))
# Out:
# <img src="data:image/png;base64,..." width="678">

# %%
ppm.plot_boundary_evolution(data_path,None,None,r_int=True,r_ref=13.,gamma = 5./3.,insert = True,
                       lims = [0., 2e3,27.6, 28.4],sparse=20)
# Out:
# /home/user/test2/test/ppmpy/ppm.py:5965: RuntimeWarning: invalid value encountered in true_divide
#   A = p/rho**gamma
# /home/user/test2/test/ppmpy/ppm.py:5974: RuntimeWarning: invalid value encountered in greater
#   idx_top = np.argmax(rel_diff > threshold)
# <img src="data:image/png;base64,..." width="640">
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
