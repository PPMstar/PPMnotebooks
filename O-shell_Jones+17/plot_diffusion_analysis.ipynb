# %% [markdown]
# # Diffusion Analysis

# %%
# %load_ext autoreload
# %autoreload 2
#for using custom PyPPM for development:
import sys
sys.path.insert(0, '/home/user/PyPPM/')

# %pylab nbagg
from ppmpy import ppm
import matplotlib.pyplot as pl
import os

project_dir = '/data/ppm_rpod2/YProfiles/O-shell-M25/'
data_dir = '/data/ppm_rpod2/'
ppm.set_YProf_path(project_dir)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D1 = ppm.yprofile('D1')
res = D1.Dinv(231, 331, plot_Dlt0=False, approx_D = True, linelims = [7.7,8.0],
        r0= 6,debug =False)
pl.xlim(7.6,8.3)
pl.ylim(7,15)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/user/PyPPM/ppmpy/ppm.py:3192: RuntimeWarning: divide by zero encountered in true_divide
#   Hp = - P[1:] * np.diff(rr) / np.diff(P)
# (7, 15)

# %%
ppm.plot_diffusion_profiles('D2',data_dir + 'Stellar_models/O-shell-M25/M25Z0.02/',28900,
                        7.8489,(1,160),2.*460.,7.8282,10.**12.27,0.21,0.055,1.6)
pl.xlim(3,9)
pl.ylim(11,16)
# Out:
# /home/user/PyPPM/ppmpy/ppm.py:2840: RuntimeWarning: divide by zero encountered in true_divide
#   Hp = - P[1:] * np.diff(r) / np.diff(P)
# 1386 in profiles.index file ...
# Found and load nearest profile for cycle 28900
# reading /data/ppm_rpod2/Stellar_models/O-shell-M25/M25Z0.02//LOGS/log593.data ...
#  reading ...25%
# /home/user/PyPPM/ppmpy/ppm.py:7345: RuntimeWarning: divide by zero encountered in true_divide
#   Hp = - P[1:] * np.diff(r) * 1.e8 / np.diff(P)
# /home/user/PyPPM/ppmpy/ppm.py:7347: RuntimeWarning: invalid value encountered in multiply
#   Dav = (1./3.) * vav * alpha * Hp
#  reading ...100%
# /home/user/PyPPM/ppmpy/ppm.py:7360: RuntimeWarning: invalid value encountered in multiply
#   Dav2 = (1./3.) * vav * np.minimum(alpha * Hp,rtop*1.e8-r*1.e8)
# <img src="data:image/png;base64,..." width="640">
# Closing profile tool ...
# /home/user/PyPPM/ppmpy/ppm.py:7363: RuntimeWarning: divide by zero encountered in log10
# ...
