# %% [markdown]
# # Diffusion Analysis

# %%
#for using custom PyPPM for development:
import sys
sys.path.insert(0, '/home/user/test2/test/')

# %pylab nbagg
from ppmpy import ppm
import matplotlib.pyplot as pl
import os

data_dir = '/data/ppm_rpod2/YProfiles/O-shell-M25/'
ppm.set_YProf_path(data_dir)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ppm.plot_diffusion_profiles('D2','/data/ppm_rpod2/Stellar_models/O-shell-M25/M25Z0.02/',28900,
                        7.8489,(1,160),2.*460.,7.8282,10.**12.27,0.21,0.055,1.6)
pl.xlim(3,9)
pl.ylim(11,16)
# Out:
# 1386 in profiles.index file ...
# Found and load nearest profile for cycle 28900
# reading /data/ppm_rpod2/Stellar_models/O-shell-M25/M25Z0.02//LOGS/log593.data ...
#  reading ...100%
# <img src="data:image/png;base64,..." width="640">
# Closing profile tool ...
# (11, 16)

# %%
D1 = ppm.yprofile('D1')
D1.Dinv(231, 331, plot_Dlt0=False, approx_D = True, linelims = [7.7,8.0],
        r0= 6)
pl.xlim(7.6,8.3)
pl.ylim(7,15)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/user/test2/test/ppmpy/ppm.py:3140: RuntimeWarning: divide by zero encountered in log10
#   pl.plot(xlong,np.log10(y0long),\
# /home/user/test2/test/ppmpy/ppm.py:3145: RuntimeWarning: divide by zero encountered in log10
#   pl.plot(xlong,np.log10(y1long),\
# /home/user/test2/test/ppmpy/ppm.py:3158: RuntimeWarning: divide by zero encountered in log10
#   pl.plot(x/1.e8,np.log10(D),'k-',\
# /home/user/test2/test/ppmpy/ppm.py:3178: RuntimeWarning: divide by zero encountered in true_divide
#   Hp = - P[1:] * np.diff(rr) / np.diff(P)
# (7, 15)
