# %% [markdown]
# # Spherically-averaged total, radial and tangential fluid velocity  components

# %%
import sys
sys.path.insert(0, '/user/jericho/PyPPM')
from ppm import *
# %matplotlib nbagg

# %%
D1 = yprofile('/data/ppm_rpod2/YProfiles/O-shell-M25/D1')
D1.vprofs( [0,200],fname_type = 'range', initial_conv_boundaries = False)
# Out:
# <img src="data:image/png;base64,..." width="640">
