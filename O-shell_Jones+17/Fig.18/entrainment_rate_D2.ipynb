# %% [markdown]
# # Entrainment rate in the D2 run

# %%
import sys
sys.path.insert(0, '/user/jericho/PyPPM')
from ppm import *
# %matplotlib nbagg

# %%
prof = yprofile('/data/ppm_rpod2/YProfiles/O-shell-M25/D2')

# %%
mdot = prof.entrainment_rate(range(150, 332, 1), 7.5, 8.5, var = 'vxz', criterion = 'min_grad', offset = -1., \
       integrate_both_fluids = False, ifig0 = 3, mdot_curve_label = r'D2 $\left( 768^3 \right)$')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
