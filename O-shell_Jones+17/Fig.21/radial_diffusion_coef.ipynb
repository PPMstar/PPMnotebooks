# %%
import sys
sys.path.insert(0, '/user/jericho/PyPPM')
import nugridpy.mesa as ms
import nugridpy.astronomy as ast
import ppm as ppm
import nugridpy.utils as utils
from matplotlib.pyplot import *
# %matplotlib nbagg

cb = utils.colourblind
lsty = utils.linestyle

data_dir = '/data/ppm_rpod2/YProfiles/O-shell-M25/'
run = 'D1'

prof = 598
dir  = '/data/ppm_rpod2/Stellar_models/O-shell-M25/M25Z0.02/'

YY=ppm.yprofile(data_dir+run)

#YY.Dinv(2,140,newton=True,plot_Dlt0=False)
#YY.Dsolvedown(2,140,newton=True,smooth=False)
#YY.Dsolvedown(2,140,newton=True,smooth=False)

# D results from Austin's work (see info in data file "" for details)
 
R = [ 3.94935,  3.96211,  3.97487,  3.98763,  4.00039,  4.01315,
         4.02591,  4.03867,  4.05143,  4.06419,  4.07695,  4.08971,
         4.10247,  4.11523,  4.12799,  4.14076,  4.15352,  4.16628,
         4.17904,  4.1918 ,  4.20456,  4.21732,  4.23008,  4.24284,
         4.2556 ,  4.26836,  4.28112,  4.29388,  4.30664,  4.3194 ,
         4.33216,  4.34492,  4.35768,  4.37044,  4.3832 ,  4.39596,
         4.40872,  4.42148,  4.43424,  4.44701,  4.45977,  4.47253,
         4.48529,  4.49805,  4.51081,  4.52357,  4.53633,  4.54909,
         4.56185,  4.57461,  4.58737,  4.60013,  4.61289,  4.62565,
         4.63841,  4.65117,  4.66393,  4.67669,  4.68945,  4.70221,
         4.71497,  4.72773,  4.74049,  4.75326,  4.76602,  4.77878,
         4.79154,  4.8043 ,  4.81706,  4.82982,  4.84258,  4.85534,
         4.8681 ,  4.88086,  4.89362,  4.90638,  4.91914,  4.9319 ,
         4.94466,  4.95742,  4.97018,  4.98294,  4.9957 ,  5.00846,
         5.02122,  5.03398,  5.04674,  5.05951,  5.07227,  5.08503,
         5.09779,  5.11055,  5.12331,  5.13607,  5.14883,  5.16159,
         5.17435,  5.18711,  5.19987,  5.21263,  5.22539,  5.23815,
         5.25091,  5.26367,  5.27643,  5.28919,  5.30195,  5.31471,
         5.32747,  5.34023,  5.35299,  5.36576,  5.37852,  5.39128,
         5.40404,  5.4168 ,  5.42956,  5.44232,  5.45508,  5.46784,
         5.4806 ,  5.49336,  5.50612,  5.51888,  5.53164,  5.5444 ,
         5.55716,  5.56992,  5.58268,  5.59544,  5.6082 ,  5.62096,
         5.63372,  5.64648,  5.65924,  5.67201,  5.68477,  5.69753,
         5.71029,  5.72305,  5.73581,  5.74857,  5.76133,  5.77409,
         5.78685,  5.79961,  5.81237,  5.82513,  5.83789,  5.85065,
         5.86341,  5.87617,  5.88893,  5.90169,  5.91445,  5.92721,
         5.93997,  5.95273,  5.96549,  5.97826,  5.99102,  6.00378,
         6.01654,  6.0293 ,  6.04206,  6.05482,  6.06758,  6.08034,
         6.0931 ,  6.10586,  6.11862,  6.13138,  6.14414,  6.1569 ,
         6.16966,  6.18242,  6.19518,  6.20794,  6.2207 ,  6.23346,
         6.24622,  6.25898,  6.27174,  6.28451,  6.29727,  6.31003,
         6.32279,  6.33555,  6.34831,  6.36107,  6.37383,  6.38659,
         6.39935,  6.41211,  6.42487,  6.43763,  6.45039,  6.46315,
          3.19712136e+14,   3.11978160e+14,   3.11669907e+14,
          3.01621571e+14,   2.97307281e+14,   2.97266027e+14,
          2.92563463e+14,   2.80058202e+14,   2.64069909e+14,
          2.48517968e+14,   2.38773802e+14,   2.34356435e+14,
          2.31085453e+14,   2.27872687e+14,   2.17523740e+14,
          2.09162252e+14,   2.08750738e+14,   2.01466690e+14,
          1.95825210e+14,   1.89205132e+14,   1.88664470e+14,
          1.80105181e+14,   1.73226955e+14,   1.66453436e+14,
          1.62091067e+14,   1.58391876e+14,   1.49772319e+14,
          1.44297724e+14,   1.41036170e+14,   1.33119378e+14,
          1.29445366e+14,   1.25899791e+14,   1.22156225e+14,
          1.15706549e+14,   1.09279986e+14,   1.04007263e+14,
          1.00021118e+14,   9.56136501e+13,   9.11662898e+13,
          8.73836530e+13,   8.46177786e+13,   8.12307726e+13,
          7.79641568e+13,   7.47751133e+13,   7.09300026e+13,
          6.72183965e+13,   6.36653788e+13,   6.10292396e+13,
          5.80555845e+13,   5.47920378e+13,   5.16703729e+13,
          4.88009002e+13,   4.55439748e+13,   4.28367808e+13,
          4.04914338e+13,   3.83473291e+13,   3.57949588e+13,
          3.35803391e+13,   3.15758918e+13,   2.94793534e+13,
          2.73100608e+13,   2.53431979e+13,   2.33557152e+13,
          2.14647336e+13,   1.96665033e+13,   1.81335856e+13,
          1.66251274e+13,   1.52242871e+13,   1.38441778e+13,
          1.24623071e+13,   1.11437958e+13,   9.91383222e+12,
          8.75307268e+12,   7.72133351e+12,   6.72223725e+12,
          5.80026154e+12,   4.94180406e+12,   4.16883706e+12,
          3.46416671e+12,   2.82624257e+12,   2.25995558e+12,
          1.77672395e+12,   1.36499624e+12,   1.02451323e+12,
          7.50539575e+11,   5.36510951e+11,   3.74914363e+11,
          2.56154307e+11,   1.70315066e+11,   1.09525312e+11,
          6.77756892e+10,   4.01730810e+10,   2.27408728e+10,
          1.23188652e+10,   6.49906185e+09,   3.49606460e+09,
          2.02620301e+09,   1.26552161e+09,   8.18726331e+08,
          5.20359271e+08,   2.62329043e+08,  -3.34741180e+07,
         -3.69771850e+08,  -5.99703770e+08,  -6.47436985e+08,
         -6.12319187e+08,  -6.00120489e+08,  -8.16804732e+08,
         -2.49782592e+09,   0.00000000e+00]


figure()

plot(R,np.log10(D),label='$\mathrm{D}$',color=cb(8))

#This is the diffusion coefficient that has been smoothed by cubic splines
# (once). It is the smoother version of the linear 'fit by hand' diffusion
# coefficient directly above.

lines=open('final_D_for_paper.txt','r').readlines()

R_cube = []
for l in lines[267:283]:
    for s in l.split():
        R_cube.append(float(s))
R_cube = np.array(R_cube)

D_cube = []
for l in lines[286:310]:
    for s in l.split():
        D_cube.append(float(s))
D_cube = np.array(D_cube)

idxhi = np.abs(R_cube-7.5).argmin()
idxlo = np.abs(R_cube-4.5).argmin()
plot(R_cube[idxlo:idxhi], np.log10(D_cube[idxlo:idxhi]),
    color='k',
    label='$\mathrm{D}\'$')

#rtop = 7.8489
rtop = 7.91
#p=ms.mesa_profile(dir+'/LOGS',model)
p=ms.mesa_profile(dir+'/LOGS',prof,num_type='profile_num')
rm = p.get('radius') * ast.rsun_cm / 1.e8
idx = np.abs(rm-rtop).argmin()
rm = rm[idx:]
Dm = p.get('log_mlt_D_mix')
Dm = Dm[idx:]
plot(rm,Dm,linestyle='--',marker='.',markevery=0.1,\
     label='$\\frac{1}{3}v_{\\rm MLT}\ell$',color=cb(4))

#v_MLT and min(l,r-r0):
hpm = p.get('pressure_scale_height') * ast.rsun_cm
ell = np.minimum( 1.6 * hpm[idx:], ( 7.902 - rm ) * 1.e8 )
v_MLT = 10. ** p.get('log_conv_vel')[idx:]
Dmp = np.log10( 1./3.* v_MLT * ell )
plot(rm,Dmp,linestyle=':',\
     label='$\\frac{1}{3}v_{\\rm MLT}\\times{\\rm min}(\ell,{\\rm r}_0-{\\rm r})$',
     color=cb(2))


# 1/3vl using v from PPM
r = YY.get('Y',fname=1,resolution='l')[::-1]
vav = YY.vaverage('vY',transient=1200.)[::-1] # cm / s
fig=gcf()
close(fig)
P = YY.get('P',fname=1)[::-1] * 1.e19 # barye, centre to surface
Hp = - P[1:] * np.diff(r) * 1.e8 / np.diff(P)
Hp = np.insert(Hp,0,0)
alpha=1.6
Dav = (1./3.) * vav * alpha * Hp
no = np.where(r>8.08)
Dav[no] = 0.
no = np.where(r<4.1)
Dav[no] = 0.
idxhi=np.abs(r-8.08).argmin()
idxlo=np.abs(r-4.1).argmin()
plot(r[idxlo:idxhi],np.log10(Dav[idxlo:idxhi]),'-.',marker='o',markevery=0.1,color=cb(3),\
     label='$\\frac{1}{3}v_\mathrm{PPM}\ell$')


# now using min ( Hp, distance ):
Dav2 = (1./3.) * vav * np.minimum(alpha * Hp,rtop*1.e8-r*1.e8)
# same at bottom boundary:
#bot=np.where(r - 6. < 0)
#Dav2[bot] = (1./3.) * vav[bot] * np.minimum(alpha * Hp[bot], np.maximum(r[bot]*1.e8-4.1e8,0))

plot(r[np.where(Dav2>0.)],np.log10(Dav2[np.where(Dav2>0.)]),color=cb(5),marker='*',markevery=0.1,\
     label='$\\frac{1}{3}{\\rm v}_\mathrm{PPM}\\times{\\rm min}(\ell,{\\rm r}_0-{\\rm r})$')

legend(loc='lower center',prop={'size':6},ncol=2).draw_frame(True)
frame=gca().get_legend().get_frame()
frame.set_edgecolor('w')

ylabel('$\log_{10}\mathrm{D\,/\,cm}^2\,\mathrm{s}^{-1}$')
xlabel('$\mathrm{r\,/\,Mm}$')
ylim(11,16)
xlim(4.1,8.0)


# figure for velocities
figure()
plot(r,vav/1.26,label='$\langle v_\mathrm{r}^\mathrm{PPM}$')
plot(rm,v_MLT,label='MESA')
ylabel('$v/\mathrm{\,cm}^2\,\mathrm{s}^{-1}$')
xlabel('$\mathrm{r\,/\,Mm}$')
xlim(4.1,8.0)
# Out:
# <img src="data:image/png;base64,..." width="1017">
# reading /data/ppm_rpod2/Stellar_models/O-shell-M25/M25Z0.02//LOGS/log598.data ...
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:201: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:201: RuntimeWarning: invalid value encountered in log10
#  reading ...100%
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:273: RuntimeWarning: invalid value encountered in log10
# <img src="data:image/png;base64,..." width="1017">
# /user/jericho/PyPPM/ppm.py:4338: RuntimeWarning: divide by zero encountered in log10
#   pl.plot(Y,np.log10(vav),'r-')
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:284: RuntimeWarning: divide by zero encountered in divide
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:287: RuntimeWarning: invalid value encountered in multiply
# ...
