# %% [markdown]
# # Radial Buckets

# %%
#for using custom PyPPM for development:
import sys
sys.path.insert(0, '/home/user/test2/test/')

# %pylab nbagg
from ppmpy import ppm
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_path = "/data/ppm_rpod2/RProfiles/O-shell-M25/D15/"
ppm.upper_bound_ut(data_path, 121, 101, 135,7.4,8.4, derivative = True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-07fbefbce0bb> in <module>()
#       1 data_path = "/data/ppm_rpod2/RProfiles/O-shell-M25/D15/"
# ----> 2 ppm.upper_bound_ut(data_path, 121, 101, 135,7.4,8.4, derivative = True)
#
# ~/test2/test/ppmpy/ppm.py in upper_bound_ut(data_path, dump_to_plot, hist_dump_min, hist_dump_max, r1, r2, ylims, derivative, silent)
#    5381     cb = utils.colourblind
#    5382     rp_set = rprof.rprofile_set(data_path)
# -> 5383     rp = rp_set.get_dump(dump_to_plot)
#    5384     nr = len(rp.get('y'))
#    5385
#
# ~/rprofile3.py in get_dump(self, dump)
#     123       return None
#     124
# --> 125     return self.ray_profiles.get(dump, rprofile(self.dump_map[dump], lazy=self.lazy, logging=self._logging))
#     126
#     127   def get_file_list_for_path(self, path):
#
# ~/rprofile3.py in __init__(self, filename, lazy, **kwargs)
# ...

# %%
ppm.upper_bound_ut(data_path, 121, 101, 135,r1 = 7.4,r2 = 8.4, derivative = False)
# Out:
# <img src="data:image/png;base64,..." width="678">

# %%
ppm.plot_boundary_evolution(data_path,7.4, 8.4, t_fit_start=700,sparse = 1)
# Out:
# <img src="data:image/png;base64,..." width="640">
