# %%
# %pylab nbagg
from ppmpy import ppm
data_dir='/ppm_data1/rpod2/YProfiles/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Tese are the projects for which data is available
# !ls /ppm_data1/rpod2/YProfiles/
# Out:
# AGBTP_M2.0Z1.e-5  agb-entrainment-convergence
# C-ingestion	  sakurai
# O-shell-M25	  sakurai-num-exp-robustness-onset-GOSH
# RAWD

# %%
# select project 
project='O-shell-M25'

# %%
ppm.set_YProf_path(data_dir+project)

# %%
# show the available cases for this project (case=run):
ppm.cases
# Out:
# ['D10',
#  'D11',
#  'D14',
#  'D23',
#  'D17',
#  'D4',
#  'D24b',
#  'D1_toomuchoutput',
#  'D5',
#  'D3',
#  'D9',
#  'D22',
#  'D15',
#  'D16',
#  'D8',
#  'D1',
#  'D18',
#  'D6',
#  'D12',
#  'D20',
#  'D24a',
#  'D21',
#  'D2']

# %%
# initialize some cases
d1=ppm.yprofile('D1')
d2=ppm.yprofile('D2')
# Out:
# Reading attributes from file  YProfile-01-0331.bobaaa
# Analyzing headers ...
# There are 332 YProfile files in the /ppm_data1/rpod2/YProfiles/O-shell-M25/D1 directory.
# Ndump values range from 0 to 331
# Time values range from 0.0 to 3310.0
# Reading attributes from file  YProfile-01-0163.bobaaa
# Analyzing headers ...
# There are 164 YProfile files in the /ppm_data1/rpod2/YProfiles/O-shell-M25/D2 directory.
# Ndump values range from 0 to 163
# Time values range from 0.0 to 1640.0

# %%
# plot a profile
ifig=109;close(ifig);figure(ifig)
#ything='FV H+He'
ything='A'
cycs=[0,100]
d1.prof_time(cycs,yaxis_thing=ything,radtop=8.0848,ifig=ifig,ls_offset=10,label_case='D1')
d2.prof_time(cycs,yaxis_thing=ything,radtop=8.0848,ifig=ifig,ls_offset=5,label_case='D2')

xlim(3.5,9.2)
#ylim(-8,0)    # FV H+He
ylim(0.10209, 0.10262) # log A
# Out:
# <img src="data:image/png;base64,...">
# (0.10209, 0.10262)

# %%
# plot a profile
ifig=110;close(ifig);figure(ifig)
ything='FV H+He'
#ything='A'
cycs=[0,100]
d1.prof_time(cycs,yaxis_thing=ything,radtop=8.0848,ifig=ifig,ls_offset=10,\
             label_case='D1, 768',logy=True)
d2.prof_time(cycs,yaxis_thing=ything,radtop=8.0848,ifig=ifig,ls_offset=5,\
             label_case='D2, 1536',logy=True)

xlim(3.5,9.2)
ylim(-4,0)    # FV H+He
#ylim(0.10209, 0.10262) # log A
# Out:
# <img src="data:image/png;base64,...">
# (-4, 0)

# %%
ylim()
# Out:
# (0.10209712982177736, 0.10262691497802735)
